// %%
%use ktor-client, kandy-geo

// %%
import org.jetbrains.kotlinx.dataframe.*
import org.jetbrains.letsPlot.core.spec.plotson.scale

val trackPoints = GeoDataFrame.readGeoJson("../resources/track_points.geojson")
val trackLines = GeoDataFrame.readGeoJson("../resources/tracks.geojson")
trackPoints.df

trackPoints.plot { geoPoints {  } }


val romania = GeoDataFrame.readGeoJson("../resources/romania.geojson")
romania.df

val minLon = 25.8
val maxLon = 26.1
val minLat = 45.44
val maxLat = 45.54


romania.plot {
    geoMap {
        borderLine.color = Color.BLACK
        fillColor = Color.GREY
    }
    layout.size = 1500 to 1500
    layout.style {
        panel {
            background {
                fillColor = Color.hex("#202050")
            }
        }
    }

    x.axis.limits = minLon..maxLon
    y.axis.limits = minLat..maxLat

    withData(trackPoints) {
        geoPoints {
            color = Color.RED
        }
    }

    withData(trackLines) {
        geoPath {
            color = Color.BLACK
        }
    }
}
// Out:
//             <iframe src='about:blank' style='border:none !important;' width='1500' height='1500' srcdoc="&lt;html lang=&quot;en&quot;>
//    &lt;head>
//        &lt;meta charset=&quot;UTF-8&quot;>
//        &lt;style> html, body { margin: 0; padding: 0; overflow: hidden; } &lt;/style>
//        &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;library&quot; src=&quot;https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.5.1/js-package/distr/lets-plot.min.js&quot;>&lt;/script>
//    &lt;/head>
//    &lt;body>
//           &lt;div id=&quot;4dkEDo&quot;>&lt;/div>
//    &lt;script type=&quot;text/javascript&quot; data-lets-plot-script=&quot;plot&quot;>
//
//    (function() {
//    // ----------
//
//    const forceImmediateRender = false;
//    const responsive = false;
//
//    let sizing = {
//        width_mode: &quot;FIXED&quot;,
//        height_mode: &quot;FIXED&quot;,
//        width: 1500.0,
//        height: 1500.0
//    };
//
// ...
